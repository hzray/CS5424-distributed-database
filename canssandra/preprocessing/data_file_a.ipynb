# %% [markdown]
# For each entity set:
#
#     1. add column names
#
#     2. find columns contain null value
#
#     3. change null as int: -1, text: 'unknown', timestamp: '1970-01-01 00:00:00'

# %%
import pandas as pd

# %%
warehouse = pd.read_csv('warehouse.csv', header=None)

# %%
warehouse.columns = ['w_id', 'w_name', 'w_street_1', 'w_street_2', 'w_city', 'w_state', 'w_zip', 'w_tax', 'w_ytd']

# %%
warehouse.isna().any()
# Out:
# w_id          False
# w_name        False
# w_street_1    False
# w_street_2    False
# w_city        False
# w_state       False
# w_zip         False
# w_tax         False
# w_ytd         False
# dtype: bool

# %%
district = pd.read_csv('district.csv', header=None)

# %%
district.columns = ['d_w_id', 'd_id', 'd_name', 'd_street_1', 'd_street_2', 'd_city', 'd_state', 'd_zip', 'd_tax',
                   'd_ytd', 'd_next_o_id']

# %%
district.isna().any()
# Out:
# d_w_id         False
# d_id           False
# d_name         False
# d_street_1     False
# d_street_2     False
# d_city         False
# d_state        False
# d_zip          False
# d_tax          False
# d_ytd          False
# d_next_o_id    False
# dtype: bool

# %%
customer = pd.read_csv('customer.csv', header=None)

# %%
customer.columns = ['c_w_id', 'c_d_id', 'c_id', 'c_first', 'c_middle', 'c_last', 'c_street_1', 'c_street_2', 'c_city',
                   'c_state', 'c_zip', 'c_phone', 'c_since', 'c_credit', 'c_credit_lim', 'c_discount', 'c_balance', 
                   'c_ytd_payment', 'c_payment_cnt', 'c_delivery_cnt', 'c_data']

# %%
customer.isna().any()
# Out:
# c_w_id            False
# c_d_id            False
# c_id              False
# c_first           False
# c_middle          False
# c_last            False
# c_street_1        False
# c_street_2        False
# c_city            False
# c_state            True
# c_zip             False
# c_phone           False
# c_since           False
# c_credit          False
# c_credit_lim      False
# c_discount        False
# c_balance         False
# c_ytd_payment     False
# c_payment_cnt     False
# c_delivery_cnt    False
# c_data            False
# dtype: bool

# %%
customer['c_state'] = customer['c_state'].fillna('unknown')

# %%
orders = pd.read_csv('order.csv', header=None)

# %%
orders.columns = ['o_w_id', 'o_d_id', 'o_id', 'o_c_id', 'o_carrier_id', 'o_ol_cnt', 'o_all_local', 'o_entry_d']

# %%
orders.isna().any()
# Out:
# o_w_id          False
# o_d_id          False
# o_id            False
# o_c_id          False
# o_carrier_id     True
# o_ol_cnt        False
# o_all_local     False
# o_entry_d       False
# dtype: bool

# %%
orders['o_carrier_id'] = orders['o_carrier_id'].fillna(-1)

# %%
item = pd.read_csv('item.csv', header=None)

# %%
item.columns = ['i_id', 'i_name', 'i_price', 'i_im_id', 'i_data']

# %%
item.isna().any()
# Out:
# i_id       False
# i_name     False
# i_price    False
# i_im_id    False
# i_data     False
# dtype: bool

# %%
order_line = pd.read_csv('order-line.csv', header=None)

# %%
order_line.columns = ['ol_w_id', 'ol_d_id', 'ol_o_id', 'ol_number', 'ol_i_id', 'ol_delivery_d', 'ol_amount', 'ol_supply_w_id',
                     'ol_quantity', 'ol_dist_info']

# %%
order_line.isna().any()
# Out:
# ol_w_id           False
# ol_d_id           False
# ol_o_id           False
# ol_number         False
# ol_i_id           False
# ol_delivery_d      True
# ol_amount         False
# ol_supply_w_id    False
# ol_quantity       False
# ol_dist_info      False
# dtype: bool

# %%
order_line
# Out:
#          ol_w_id  ol_d_id  ol_o_id  ol_number  ol_i_id  \
# 0              1        1        1          1    20822
# 1              1        1        1          2    62266
# 2              1        1        1          3    47297
# 3              1        1        1          4    61218
# 4              1        1        1          5    57008
# ...          ...      ...      ...        ...      ...
# 3748844       10       10     3000         15    58777
# 3748845       10       10     3000         16    91714
# 3748846       10       10     3000         17    43811
# 3748847       10       10     3000         18    98169
# 3748848       10       10     3000         19    96498
#
#                    ol_delivery_d  ol_amount  ol_supply_w_id  ol_quantity  \
# 0        2021-08-27 09:50:32.527       0.00               1            5
# 1        2021-08-27 09:50:32.527       0.00               1            5
# 2        2021-08-27 09:50:32.527       0.00               1            5
# 3        2021-08-27 09:50:32.527       0.00               1            5
# 4        2021-08-27 09:50:32.527       0.00               1            5
# ...                          ...        ...             ...          ...
# 3748844                      NaN    5295.01              10            5
# 3748845                      NaN    7251.23              10            5
# 3748846                      NaN    2327.84              10            5
# 3748847                      NaN    2874.15              10            5
# 3748848                      NaN    5730.80              10            5
#
#                     ol_dist_info
# 0        fjuwillmmaqaqzbqesyifas
# 1        bbooaqpuuddhkyqephoaszo
# 2        zfzmqutfxfvqpldlsjqbivz
# 3        ochisuyvhtrtocfyifwyydd
# 4        gfchgbullzaliifvmkueqgw
# ...                          ...
# 3748844  ygegziqpgynjkubufakampl
# 3748845  knzjapuugkjhpkbcgkonujc
# 3748846  qrgnecokgbyqxjutulssekx
# 3748847  hfefxneahqjjhfzxkoxqjqp
# 3748848  hytcvvkpsxyuzimaffbesvm
#
# [3748849 rows x 10 columns]

# %%
order_line['ol_delivery_d'] = order_line['ol_delivery_d'].fillna(pd.Timestamp(0))

# %%
order_line
# Out:
#          ol_w_id  ol_d_id  ol_o_id  ol_number  ol_i_id  \
# 0              1        1        1          1    20822
# 1              1        1        1          2    62266
# 2              1        1        1          3    47297
# 3              1        1        1          4    61218
# 4              1        1        1          5    57008
# ...          ...      ...      ...        ...      ...
# 3748844       10       10     3000         15    58777
# 3748845       10       10     3000         16    91714
# 3748846       10       10     3000         17    43811
# 3748847       10       10     3000         18    98169
# 3748848       10       10     3000         19    96498
#
#                    ol_delivery_d  ol_amount  ol_supply_w_id  ol_quantity  \
# 0        2021-08-27 09:50:32.527       0.00               1            5
# 1        2021-08-27 09:50:32.527       0.00               1            5
# 2        2021-08-27 09:50:32.527       0.00               1            5
# 3        2021-08-27 09:50:32.527       0.00               1            5
# 4        2021-08-27 09:50:32.527       0.00               1            5
# ...                          ...        ...             ...          ...
# 3748844      1970-01-01 00:00:00    5295.01              10            5
# 3748845      1970-01-01 00:00:00    7251.23              10            5
# 3748846      1970-01-01 00:00:00    2327.84              10            5
# 3748847      1970-01-01 00:00:00    2874.15              10            5
# 3748848      1970-01-01 00:00:00    5730.80              10            5
#
#                     ol_dist_info
# 0        fjuwillmmaqaqzbqesyifas
# 1        bbooaqpuuddhkyqephoaszo
# 2        zfzmqutfxfvqpldlsjqbivz
# 3        ochisuyvhtrtocfyifwyydd
# 4        gfchgbullzaliifvmkueqgw
# ...                          ...
# 3748844  ygegziqpgynjkubufakampl
# 3748845  knzjapuugkjhpkbcgkonujc
# 3748846  qrgnecokgbyqxjutulssekx
# 3748847  hfefxneahqjjhfzxkoxqjqp
# 3748848  hytcvvkpsxyuzimaffbesvm
#
# [3748849 rows x 10 columns]

# %%
stock = pd.read_csv('stock.csv', header=None)

# %%
stock.columns = ['s_w_id', 's_i_id', 's_quantity', 's_ytd', 's_order_cnt', 's_remote_cnt', 's_dist_01', 's_dist_02', 's_dist_03', 's_dist_04', 's_dist_05',
                's_dist_06','s_dist_07', 's_dist_08', 's_dist_09', 's_dist_10', 's_data']

# %%
stock.isna().any()
# Out:
# s_w_id          False
# s_i_id          False
# s_quantity      False
# s_ytd           False
# s_order_cnt     False
# s_remote_cnt    False
# s_dist_01       False
# s_dist_02       False
# s_dist_03       False
# s_dist_04       False
# s_dist_05       False
# s_dist_06       False
# s_dist_07       False
# s_dist_08       False
# s_dist_09       False
# s_dist_10       False
# s_data          False
# dtype: bool

# %%
warehouse.to_csv('warehouse.csv', index=False)

# %%
district.to_csv('district.csv', index=False)

# %%
customer.to_csv('customer.csv', index=False)

# %%
orders.to_csv('order.csv', index=False)

# %%
item.to_csv('item.csv', index=False)

# %%
order_line.to_csv('order-line.csv', index=False)

# %%
stock.to_csv('stock.csv', index=False)

# %%
orders
# Out:
#         o_w_id  o_d_id  o_id  o_c_id  o_carrier_id  o_ol_cnt  o_all_local  \
# 0            1       1     1    2607           2.0        13            1
# 1            1       1     2    2123           8.0        14            1
# 2            1       1     3    2637          10.0        18            1
# 3            1       1     4    2748           7.0        12            1
# 4            1       1     5    1173           3.0        10            1
# ...        ...     ...   ...     ...           ...       ...          ...
# 299995      10      10  2996    2780          -1.0        10            1
# 299996      10      10  2997    1604          -1.0        17            1
# 299997      10      10  2998    2126          -1.0         5            1
# 299998      10      10  2999     642          -1.0        13            1
# 299999      10      10  3000    1314          -1.0        19            1
#
#                       o_entry_d
# 0       2021-08-27 09:50:32.527
# 1       2021-08-27 09:50:32.527
# 2       2021-08-27 09:50:32.527
# 3       2021-08-27 09:50:32.527
# 4       2021-08-27 09:50:32.527
# ...                         ...
# 299995   2021-08-27 09:50:40.33
# 299996   2021-08-27 09:50:40.33
# 299997   2021-08-27 09:50:40.33
# 299998   2021-08-27 09:50:40.33
# 299999   2021-08-27 09:50:40.33
#
# [300000 rows x 8 columns]

# %%
customer_order_items = order_line[['ol_w_id', 'ol_d_id', 'ol_o_id', 'ol_number', 'ol_i_id']]

# %%
customer_order_items.columns = ['o_w_id', 'o_d_id', 'o_id', 'ol_number', 'ol_i_id']

# %%
customer_order_items
# Out:
#          o_w_id  o_d_id  o_id  ol_number  ol_i_id
# 0             1       1     1          1    20822
# 1             1       1     1          2    62266
# 2             1       1     1          3    47297
# 3             1       1     1          4    61218
# 4             1       1     1          5    57008
# ...         ...     ...   ...        ...      ...
# 3748844      10      10  3000         15    58777
# 3748845      10      10  3000         16    91714
# 3748846      10      10  3000         17    43811
# 3748847      10      10  3000         18    98169
# 3748848      10      10  3000         19    96498
#
# [3748849 rows x 5 columns]

# %%
customer_order_items = pd.merge(customer_order_items, orders, on=['o_w_id', 'o_d_id', 'o_id'], how='left')

# %%
customer_order_items = customer_order_items[['o_w_id', 'o_d_id', 'o_id', 'ol_i_id', 'o_c_id']]

# %%
customer_order_items.columns = [['coi_w_id', 'coi_d_id', 'coi_o_id', 'coi_i_id', 'coi_c_id']]

# %%
customer_order_items
# Out:
#         coi_w_id coi_d_id coi_o_id coi_i_id coi_c_id
# 0              1        1        1    20822     2607
# 1              1        1        1    62266     2607
# 2              1        1        1    47297     2607
# 3              1        1        1    61218     2607
# 4              1        1        1    57008     2607
# ...          ...      ...      ...      ...      ...
# 3748844       10       10     3000    58777     1314
# 3748845       10       10     3000    91714     1314
# 3748846       10       10     3000    43811     1314
# 3748847       10       10     3000    98169     1314
# 3748848       10       10     3000    96498     1314
#
# [3748849 rows x 5 columns]

# %%
customer_order_items.to_csv('customer_order_line.csv', index=False)
